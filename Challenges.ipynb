# %%
import pandas as pd # library for data manipulation
import matplotlib.pyplot as plt # library for visualization
import seaborn as sns # library for visualization
sns.set() # this command sets the seaborn chart style as the default

# %%
Challenges = pd.read_excel("Challenges.xlsx")

# %%
Challenges
# Out:
#                                            Challenge  Number of Respondents
# 0  Cancellation of the trip due to destination ac...                     30
# 1    Increase in fares during periods of high demand                    105
# 2                          Unsafe driving by drivers                     18
# 3                       Hostile behaviour of drivers                     23
# 4  The difficulty of the driver locating the pick...                     75

# %%
y = ["Cancellation of the trip due to destination accessibility", "Increase in fares during periods of high demand", "Unsafe driving by drivers", "Hostile behaviour of drivers", "The difficulty of the driver locating the pickup point"]
w = [30,105,18,23,75]
c = ['Purple','Orange','Blue','Violet','Red']
plt.barh(y,w,0.5,color = c)
plt.ylabel("Challenge", fontsize = 13)
plt.xlabel("Number of Respondents", fontsize = 13)
plt.title("Challenges associated with the use of ride-hailing services", fontsize = 16, fontweight = "bold")
plt.savefig("Challenges associated with the use of ride-hailing services.png", bbox_inches='tight') # you can export your chart as a picture
plt.show()
