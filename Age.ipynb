# %%
import pandas as pd # library for data manipulation
import matplotlib.pyplot as plt # library for visualization
import seaborn as sns # library for visualization
sns.set() # this command sets the seaborn chart style as the default

# %%
Age = pd.read_excel("Age.xlsx")

# %%
Age
# Out:
#            Age  Number of Respondents
# 0  20 or under                     73
# 1        21-30                    121
# 2        31-40                     40
# 3        41-50                     15
# 4          50+                      2

# %%
plt.figure(figsize = (9, 6)) #determine the size of the chart
# To create a bar chart with matplotlib you can use the 'bar' function.
plt.bar(x = Age["Age"], #specify the x axis
        height = Age["Number of Respondents"], #specify the y axis
        color = ['midnightblue','Green','Blue','Cyan','Red']) # the color for the bars
plt.xticks(rotation = 360, fontsize = 10) # rotate and format the labels for the x-axis
plt.yticks(fontsize = 13) # format the y-axis
plt.title("Age of Respondents", fontsize = 16, fontweight = "bold") #add and format the title for the chart
plt.xlabel("Age", fontsize = 13 ) #add a title for the x-axis
plt.ylabel("Number of Respondents", fontsize = 13 ) #add a title for the y-axis
plt.savefig("Age of Respondents.png", bbox_inches='tight') # you can export your chart as a picture
plt.show() # depending on which environment you're using without this line you're chart may not display properly.
